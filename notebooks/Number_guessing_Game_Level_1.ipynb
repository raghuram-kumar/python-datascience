# %% [markdown]
# <a href="https://colab.research.google.com/github/raghuram-kumar/python-datascience/blob/main/notebooks/Number_guessing_Game_Level_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Number Guessing Game Level 1

# %% [markdown]
# ## 1. Print if tge user guessed number is right or not.

# %%
secret_number = 56

user_input = int(input("Enter your guess:"))

if secret_number == user_input:
    print("Congratulations! You're guess is right!")
else:
    print("Sorry. Your guess is wrong")
# Out:
# Enter your guess:56
# Congratulations! You're guess is right!

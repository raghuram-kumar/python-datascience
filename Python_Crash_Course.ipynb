# %% [markdown]
# <a href="https://colab.research.google.com/github/raghuram-kumar/python-datascience/blob/main/Python_Crash_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Number Guessing Game

# %% [markdown]
# ## Level 1. Print if tge user guessed number is right or not.

# %%
secret_number = 56

user_input = int(input("Enter your guess:"))

if secret_number == user_input:
    print("Congratulations! You're guess is right!")
else:
    print("Sorry. Your guess is wrong")
# Out:
# Enter your guess:56
# Congratulations! You're guess is right!

# %% [markdown]
# ### Importance of Datatypes
#
# 1. Int
# 2. Float
# 3. Boolean
# 4. Str - "Anything which is enclosed in quotes"

# %% [markdown]
# ## Level 2. Print if the user guessed number is right or not but with max of 7 trials

# %% [markdown]
# #### 2.1 Using For Loop - end interation number is defined

# %%
secret_number = 56

for i in range(0,7):
    user_input = int(input("Enter your guess:"))

    if secret_number == user_input:
      print("Congratulations! You're guess is right!")
      break
    else:
      print("Sorry. Your guess is wrong")
# Out:
# Enter your guess:45
# Sorry. Your guess is wrong
# Enter your guess:56
# Congratulations! You're guess is right!

# %% [markdown]
# #### 2.2 While Loop - When end interation number is not defined and the instructions has to be executed infinite times

# %%
secret_number = 56

while True:
    user_input = int(input("Enter your guess: "))

    if secret_number == user_input:
        print("Congratulations! You're guess is right!")
        break
    else:
        print("Sorry. Your guess is wrong")
# Out:
# Enter your guess: 58
# Sorry. Your guess is wrong
# Enter your guess: 66
# Sorry. Your guess is wrong
# Enter your guess: 88
# Sorry. Your guess is wrong
# Enter your guess: 65
# Sorry. Your guess is wrong
# Enter your guess: 567
# Sorry. Your guess is wrong
# Enter your guess: 66
# Sorry. Your guess is wrong
# Enter your guess: 63
# Sorry. Your guess is wrong
# Enter your guess: 56
# Congratulations! You're guess is right!

# %% [markdown]
# ### Level 3: Give multiple Conditions
#
# 1. User should enter the number between 1-100. If it's entered wrong, the program should say, "Invalid Number"
# 2. If the user guessed number > secret number, then program should say, "Your number is greater than the secret number"
# 3. If the user guessed number < secret number, then program should say, "Your number is lesser than the secret number"

# %%
print("Welcome to Number Guessing Game!!!")
print("Guess the Number between 1 to 100")

secret_number = 98

for i in range(1, 8):
    user_input = int(input("Enter the Number: "))

    if user_input < 1 or user_input > 100:
        print("Invalid Number! Please enter the Number between 1-100")
    elif user_input > secret_number:
        print("Your Number Higher!")
    elif user_input < secret_number:
        print("Your Number Lesser!")
    else:
        print("Your Guessed Number is Correct!")
        print(f"Congratulations, You have guessed the number {secret_number} in {i} attempts")
        break
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number: 25
# Your Number Lesser!
# Enter the Number: 15
# Your Number Lesser!
# Enter the Number: 100
# Your Number Higher!
# Enter the Number: 105
# Invalid Number! Please enter the Number between 1-100
# Enter the Number: 12
# Your Number Lesser!
# Enter the Number: 98
# Your Guessed Number is Correct!
# Congratulations, You have guessed the number 98 in 6 attempts

# %% [markdown]
# ## Level 4: Setting Multiple Conditions

# %%
print("Welcome to Number Guessing Game!!!")
print("Guess the Number between 1 to 100")

secret_number = 98

for i in range(1, 8):
    user_input = int(input("Enter the Number:"))

    if user_input < 1 or user_input > 100:
        print("Invalid Number! Please enter the Number between 1-100")

    elif user_input > secret_number:
        print("Your Number Higher!")

    elif user_input < secret_number:
        print("Your Number Lesser!")

    else:
        print("Your Guessed Number is Correct!")
        break

# After loop finishes, check final result
if secret_number == user_input:
    print(f"Congratulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again!!")

# %% [markdown]
# ## Level 5: The Secret Number should'nt be fixed. It should be random.

# %%
import random

print("Welcome to Number Guessing Game!!!")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1, 100)

for i in range(1, 8):
    user_input = int(input("Enter the Number:"))

    if user_input < 1 or user_input > 100:
        print("Invalid Number! Please enter the Number between 1-100")

    elif user_input > secret_number:
        print("Your Number Higher!")

    elif user_input < secret_number:
        print("Your Number Lesser!")

    else:
        print("Your Guessed Number is Correct!")
        break

# After loop finishes, check final result
if secret_number == user_input:
    print(f"Congratulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again!!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number:65
# Your Number Lesser!
# Enter the Number:76
# Your Number Lesser!
# Enter the Number:95
# Your Number Lesser!
# Enter the Number:99
# Your Number Lesser!
# Enter the Number:100
# Your Guessed Number is Correct!
# Congratulations, You have guessed the number 100 in 5 attempts

# %% [markdown]
# #### 5.2 Remove the trial limits

# %%
import random

print("Welcome to Number Guessing Game!!!")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1, 100)

while True:
    user_input = int(input("Enter the Number:"))

    if user_input < 1 or user_input > 100:
        print("Invalid Number! Please enter the Number between 1-100")

    elif user_input > secret_number:
        print("Your Number Higher!")

    elif user_input < secret_number:
        print("Your Number Lesser!")

    else:
        print("Your Guessed Number is Correct!")
        break
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number:50
# Your Number Lesser!
# Enter the Number:70
# Your Number Higher!
# Enter the Number:60
# Your Number Higher!
# Enter the Number:51
# Your Number Lesser!
# Enter the Number:52
# Your Number Lesser!
# Enter the Number:53
# Your Number Lesser!
# Enter the Number:54
# Your Number Lesser!
# Enter the Number:55
# Your Number Lesser!
# Enter the Number:56
# Your Number Lesser!
# Enter the Number:57
# Your Guessed Number is Correct!

# %% [markdown]
# ## Level 6 - How to handle Invalid Characters or Values

# %%
import random

print("Welcome to Number Guessing Game!!!")
print("Guess the Number between 1 to 100")

secret_number = random.randint(1, 100)

for i in range(1, 8):
    try:
        user_input = int(input("Enter the Number:"))

        if user_input < 1 or user_input > 100:
            print("Invalid Number! Please enter the Number between 1-100")

        elif user_input > secret_number:
            print("Your Number Higher!")

        elif user_input < secret_number:
            print("Your Number Lesser!")

        else:
            print("Your Guessed Number is Correct!")
            break
    except ValueError:
      print("Invalid Characters, Not Recognized. Please enter the Number between 1-100 to play this game")

# After loop finishes, check final result
if secret_number == user_input:
    print(f"Congratulations, You have guessed the number {secret_number} in {i} attempts")
else:
    print("Sorry! All your trials is exceeded. Try Again!!")
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number:asas
# Invalid Characters, Not Recognized. Please enter the Number between 1-100 to play this game
# Enter the Number:52
# Your Number Lesser!
# Enter the Number:10
# Your Number Lesser!
# Enter the Number:100
# Your Number Higher!
# Enter the Number:122
# Invalid Number! Please enter the Number between 1-100
# Enter the Number:85
# Your Number Higher!
# Enter the Number:80
# Your Number Higher!
# Sorry! All your trials is exceeded. Try Again!!

# %% [markdown]
# ## Level 7 - Take this program to run as a Function when it is called
#
# Step 1: Define a Function
#
# Step 2: Call the Function

# %%
def number_guessing_game():
    import random

    print("Welcome to Number Guessing Game!!!")
    print("Guess the Number between 1 to 100")

    secret_number = random.randint(1, 100)

    for i in range(1, 8):
        try:
            user_input = int(input("Enter the Number:"))

            if user_input < 1 or user_input > 100:
                print("Invalid Number! Please enter the Number between 1-100")

            elif user_input > secret_number:
                print("Your Number Higher!")

            elif user_input < secret_number:
                print("Your Number Lesser!")

            else:
                print("Your Guessed Number is Correct!")
                break
        except ValueError:
          print("Invalid Characters, Not Recognized. Please enter the Number between 1-100 to play this game")

    # After loop finishes, check final result
    if secret_number == user_input:
        print(f"Congratulations, You have guessed the number {secret_number} in {i} attempts")
    else:
        print("Sorry! All your trials is exceeded. Try Again!!")

# %%
number_guessing_game()
# Out:
# Welcome to Number Guessing Game!!!
# Guess the Number between 1 to 100
# Enter the Number:25
# Your Number Lesser!
# Enter the Number:50
# Your Number Higher!
# Enter the Number:35
# Your Number Higher!
# Enter the Number:30
# Your Number Lesser!
# Enter the Number:32
# Your Number Lesser!
# Enter the Number:33
# Your Number Lesser!
# Enter the Number:34
# Your Guessed Number is Correct!
# Congratulations, You have guessed the number 34 in 7 attempts
